# %% [markdown]
# <a href="https://colab.research.google.com/github/amitsahoo11071989/22Jan2024/blob/main/mnist_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow

# %%
from tensorflow import keras

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Flatten

# %%
# load mnist image data in xtrain, y_train, x_test, y_test

(xtrain, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# %%
xtrain.shape
# Out:
# (60000, 28, 28)

# %%
y_train[0]
# Out:
# 5

# %%
import matplotlib.pyplot as plt
plt.imshow(xtrain[0])
plt.show()

# %%
xtrain = xtrain/255
x_test = x_test/255

# %%
xtrain[0]

# %%
model = Sequential()

model.add(Flatten(input_shape=(28,28)))
model.add(Dense(100, activation="relu"))
model.add(Dense(50, activation="relu"))
model.add(Dense(10, activation="softmax"))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense_3 (Dense)             (None, 100)               78500
#
#  dense_4 (Dense)             (None, 50)                5050
#
#  dense_5 (Dense)             (None, 10)                510
#
# ...
# Total params: 84060 (328.36 KB)
# Trainable params: 84060 (328.36 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
history = model.fit(xtrain, y_train, epochs= 20, validation_split=0.2)
# Out:
# Epoch 1/20
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.2846 - accuracy: 0.9184 - val_loss: 0.1449 - val_accuracy: 0.9588
# Epoch 2/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1234 - accuracy: 0.9634 - val_loss: 0.1103 - val_accuracy: 0.9676
# Epoch 3/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0839 - accuracy: 0.9742 - val_loss: 0.1087 - val_accuracy: 0.9676
# Epoch 4/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0642 - accuracy: 0.9801 - val_loss: 0.0969 - val_accuracy: 0.9725
# Epoch 5/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0508 - accuracy: 0.9837 - val_loss: 0.0957 - val_accuracy: 0.9742
# Epoch 6/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0423 - accuracy: 0.9862 - val_loss: 0.1016 - val_accuracy: 0.9714
# Epoch 7/20
# ...

# %%
y_pred = model.predict(x_test)
# Out:
# 313/313 [==============================] - 0s 984us/step

# %%
y_pred_number = y_pred.argmax(axis=1)

# %%
y_pred_number
# Out:
# array([7, 2, 1, ..., 4, 5, 6])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred_number)
# Out:
# 0.9781

# %%
import matplotlib.pyplot as plt

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
plt.imshow(x_test[0])

# %%
model.predict(x_test[0].reshape(1,28, -1)).argmax(axis=1)
# Out:
# 1/1 [==============================] - 0s 23ms/step
# array([7])
